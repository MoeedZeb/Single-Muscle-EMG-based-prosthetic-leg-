# %%
import pandas as pd
from sklearn.svm import SVC
from sklearn.decomposition import PCA
from sklearn.preprocessing import StandardScaler

# %% [markdown]
# PCA

# %%
'''Try to do this with different number of components'''

# Load your dataset
df = pd.read_csv(r"EMG_standfeat.csv")
X = df.drop('Label', axis=1) 
y = df['Label']


# Perform PCA
pca = PCA(n_components=15)
X_pca = pca.fit_transform(X)
print("Explained variance ratio:", pca.explained_variance_ratio_)
print("Cumulative explained variance:", np.cumsum(pca.explained_variance_ratio_))
pca_df = pd.DataFrame(X_pca, columns=[f'PC{i+1}' for i in range(15)])
pca_df['Label'] = y.values
print(pca_df.head())

# Save the new DataFrame with PCA features to a CSV file (optional)
pca_df.to_csv('"emg__pca_features.csv', index=False)
# Out:
# Explained variance ratio: [6.72152124e-01 1.91676597e-01 4.35668868e-02 3.47375406e-02
#  2.66773363e-02 1.48248537e-02 5.92916538e-03 4.72646130e-03
#  1.85829128e-03 1.55252218e-03 9.12641691e-04 6.23702450e-04
#  4.47935210e-04 2.36320726e-04 5.21319740e-05]
# Cumulative explained variance: [0.67215212 0.86382872 0.90739561 0.94213315 0.96881048 0.98363534
#  0.9895645  0.99429096 0.99614926 0.99770178 0.99861442 0.99923812
#  0.99968606 0.99992238 0.99997451]
#         PC1       PC2       PC3       PC4       PC5       PC6       PC7  \
# 0  3.035659 -6.943129  0.203323 -1.589111 -0.071053 -1.384983  0.307324
# 1  3.027011 -6.818337  0.232637 -1.468585 -0.080871 -1.207537  0.093861
# 2  3.028076 -6.919868  0.245088 -1.512597 -0.069869 -1.325136  0.138125
# 3  3.040944 -6.812592  0.227124 -1.433189 -0.108084 -1.173837  0.073879
# 4  3.055561 -6.789167  0.209990 -1.411349 -0.115277 -1.127813  0.046714
#
#         PC8       PC9      PC10      PC11      PC12      PC13      PC14  \
# ...
